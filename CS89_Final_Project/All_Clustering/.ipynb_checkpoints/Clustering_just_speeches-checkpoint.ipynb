# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
# Insspiration for tsne and top-k words: https://www.kaggle.com/code/jbencina/clustering-documents-with-tfidf-and-kmeans

# %%
# df = pd.read_csv('../All_Scraping/df_2000_to_2203.csv')
df = pd.read_csv('../Text_Scraping/FOMC_Statements_and_Minutes.csv')
df['Date'] = pd.to_datetime(df['Date']).astype('int64')
df
# Out:
#       Unnamed: 0                 Date                                Author  \
# 0              0   976233600000000000               Chairman Alan Greenspan
# 1              1   976060800000000000  Vice Chairman Roger W. Ferguson, Jr.
# 2              2   976060800000000000           Governor Edward M. Gramlich
# 3              3   975974400000000000               Chairman Alan Greenspan
# 4              4   974764800000000000           Governor Edward M. Gramlich
# ...          ...                  ...                                   ...
# 1513        1513  1674172800000000000        Governor Christopher J. Waller
# 1514        1514  1674086400000000000              Vice Chair Lael Brainard
# 1515        1515  1673308800000000000           Governor Michelle W. Bowman
# 1516        1516  1673308800000000000                Chair Jerome H. Powell
# 1517        1517  1672963200000000000                 Governor Lisa D. Cook
#
#                                                    Text  authorId  year  \
# 0      \n \n\r\nBuildings such as this new Birmingha...         0  2000
# 1      \n \n\n\r\n\tThank you for inviting me to the...         1  2000
# 2      \n \n\n Subprime Lending, Predatory Lending \...         2  2000
# 3      \n \n\r\nTechnological innovation, and in par...         0  2000
# 4      \n \n\n Financial Literacy \n \r\nPartnership...         2  2000
# ...                                                 ...       ...   ...
# 1513    Thank you, Ben, and thank you to the Council...        39  2023
# 1514    Inflation has declined in recent months, whi...        43  2023
# 1515    Governor Bowman presented identical remarks ...        36  2023
# 1516    I will address three main points. First, the...        33  2023
# 1517    I am particularly pleased to be here today f...        42  2023
#
#       quarter    Type
# 0           4  Speech
# 1           4  Speech
# 2           4  Speech
# 3           4  Speech
# 4           4  Speech
# ...       ...     ...
# 1513        1  Speech
# 1514        1  Speech
# 1515        1  Speech
# 1516        1  Speech
# 1517        1  Speech
#
# [1518 rows x 8 columns]

# %%
# Keeping the date, authorId, author, and text
df = df[['Date', 'Author', 'Text', 'authorId']]
df
# Out:
#                      Date                                Author  \
# 0      976233600000000000               Chairman Alan Greenspan
# 1      976060800000000000  Vice Chairman Roger W. Ferguson, Jr.
# 2      976060800000000000           Governor Edward M. Gramlich
# 3      975974400000000000               Chairman Alan Greenspan
# 4      974764800000000000           Governor Edward M. Gramlich
# ...                   ...                                   ...
# 1513  1674172800000000000        Governor Christopher J. Waller
# 1514  1674086400000000000              Vice Chair Lael Brainard
# 1515  1673308800000000000           Governor Michelle W. Bowman
# 1516  1673308800000000000                Chair Jerome H. Powell
# 1517  1672963200000000000                 Governor Lisa D. Cook
#
#                                                    Text  authorId
# 0      \n \n\r\nBuildings such as this new Birmingha...         0
# 1      \n \n\n\r\n\tThank you for inviting me to the...         1
# 2      \n \n\n Subprime Lending, Predatory Lending \...         2
# 3      \n \n\r\nTechnological innovation, and in par...         0
# 4      \n \n\n Financial Literacy \n \r\nPartnership...         2
# ...                                                 ...       ...
# 1513    Thank you, Ben, and thank you to the Council...        39
# 1514    Inflation has declined in recent months, whi...        43
# 1515    Governor Bowman presented identical remarks ...        36
# 1516    I will address three main points. First, the...        33
# 1517    I am particularly pleased to be here today f...        42
#
# [1518 rows x 4 columns]

# %%
#Setting TFIDF Parameters
tfidf = TfidfVectorizer(
    min_df = 5,
    max_df = 0.8,
    max_features = 8000,
    stop_words = 'english'
)
tfidf.fit(df.Text)
text = tfidf.transform(df.Text)

# %%
#Elbow method using WCSS

X = text.copy()
wcss = {} 
for i in range(1, 20): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 20, n_init = 'auto')
    kmeans.fit(X)
    wcss[i] = kmeans.inertia_
     
plt.plot(wcss.keys(), wcss.values(), 'gs-')
plt.xlabel("Values of 'k'")
plt.ylabel('WCSS')
plt.show()

# %%
#Plot PCA and TSNE Function

def plot_tsne_pca(data, labels, n):
    max_label = max(labels)
    
    # PCA
    pca = PCA(n_components=2).fit_transform(np.asarray(data.todense()))

    # t-SNE
    tsne = TSNE().fit_transform(PCA(n_components=50).fit_transform(np.asarray(data.todense())))
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[:, 0], pca[:, 1], c=labels)
    ax[0].set_title('PCA Cluster Plot of Speeches. '+str(n)+' clusters.')
    
    ax[1].scatter(tsne[:, 0], tsne[:, 1], c=labels)
    ax[1].set_title('t-SNE Cluster Plot of Speeches. '+str(n)+' clusters.')
    
# plot_tsne_pca(text, clusters)

# %%
#Plotting 4 clusters
clusters = KMeans(n_clusters=4, random_state=20).fit_predict(text)
plot_tsne_pca(text, clusters, 4)
# Out:
# /Users/jonjafarnia/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
#Getting top 10 key words
Yea
def get_top_keywords(data, clusters, labels, n_terms):
    df = pd.DataFrame(data.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords(text, clusters, tfidf.get_feature_names_out(), 10)
# Out:
# Cluster 0
# firms,credit,institutions,liquidity,management,basel,banking,capital,banks,risk
#
# Cluster 1
# states,monetary,text,percent,capital,payments,policy,education,growth,productivity
#
# Cluster 2
# growth,prices,rates,labor,percent,fomc,rate,monetary,policy,inflation
#
# Cluster 3
# housing,small,loans,lending,cra,communities,credit,mortgage,banks,community
