# %%
import quandl
import pandas_datareader.data as web
import datetime
import yfinance as yf
import pandas as pd
from datetime import datetime
import seaborn as sns
import os
import matplotlib as plt

indices_data = yf.download('^GSPC ^VIX', start='1998-12-31', end='2023-11-01')
liquidity = pd.DataFrame(indices_data['Volume']['^GSPC'])
SP_500 = pd.DataFrame(indices_data['Close']['^GSPC'])
volatility = pd.DataFrame(indices_data['Close']['^VIX'])

sent_data = web.DataReader(['UMCSENT'], 'fred', datetime(1998, 12, 31), datetime(2023, 11, 13))

quandl.ApiConfig.api_key = 'yC7JQzd6FsYXc_4F67ym'

macro_indicators = {
    '2_YR_Treasury': 'FRED/DGS2',
    'Eff_Fed_Funds': 'FRED/DFF',
    'Real_GDP': 'FRED/GDPC1',
    'Core_CPI': 'FRED/CORESTICKM159SFRBATL',
    'PCE': 'FRED/PCE',
    'Unemployment': 'FRED/UNRATE',
    'Savings_Rate': 'FRED/PSAVERT',
    'Retail_Sales': 'FRED/RETAILMPCSMSA',
    'Manufacturing_PMI': 'ISM/MAN_PMI'
}

macro_indicators_df = {}

for indicator in macro_indicators:
    quandl_code = macro_indicators[indicator]
    data = quandl.get(quandl_code)
    macro_indicators_df[indicator] = data

macro_indicators_df['Consumer_Sent'] = sent_data
macro_indicators_df['Liquidity'] = liquidity
macro_indicators_df['Volatility'] = volatility
macro_indicators_df['SP_500'] = SP_500

merged = pd.DataFrame(index= pd.date_range(start=datetime(1998,12,31), end=datetime.now(), freq='D'))
for indicator in macro_indicators_df.keys():
    merged = pd.merge(merged, macro_indicators_df[indicator], left_index=True, right_index=True, how='left')

merged.columns = list(macro_indicators_df.keys())
for col in macro_indicators_df.keys():
    merged[col] = merged[col].ffill()
    merged[col+"_pct_chng"] = merged[col].pct_change(periods=365)

merged = merged[merged.index>=datetime(1999,12,31)]
    
merged.to_csv(os.getcwd() + "/macro_indicators.csv")
# Out:
# [*********************100%%**********************]  2 of 2 completed
# <ipython-input-78-1c28e351f82d>:45: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged = pd.merge(merged, macro_indicators_df[indicator], left_index=True, right_index=True, how='left')
# <ipython-input-78-1c28e351f82d>:45: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged = pd.merge(merged, macro_indicators_df[indicator], left_index=True, right_index=True, how='left')
# <ipython-input-78-1c28e351f82d>:45: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged = pd.merge(merged, macro_indicators_df[indicator], left_index=True, right_index=True, how='left')

# %%
sns.heatmap(merged, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Macroeconomic Indicator Heatmap')
plt.show()
# Out:
#                    2_YR_Treasury  Eff_Fed_Funds  Real_GDP  Core_CPI       PCE  \
# 2_YR_Treasury           1.000000       0.958824 -0.609746  0.457399 -0.641285
# Eff_Fed_Funds           0.958824       1.000000 -0.533640  0.469427 -0.569343
# Real_GDP               -0.609746      -0.533640  1.000000 -0.192422  0.995536
# Core_CPI                0.457399       0.469427 -0.192422  1.000000 -0.188339
# PCE                    -0.641285      -0.569343  0.995536 -0.188339  1.000000
# Unemployment           -0.572556      -0.577563  0.009775 -0.602841  0.022959
# Savings_Rate           -0.495530      -0.454029  0.464188 -0.222176  0.542178
# Retail_Sales           -0.026162      -0.018977 -0.026657 -0.132346  0.036925
# Manufacturing_PMI      -0.127801      -0.192033  0.324651 -0.435600  0.309231
# Consumer_Sent           0.442322       0.500053 -0.133408  0.259626 -0.175094
# Liquidity              -0.569650      -0.552972  0.552869 -0.351867  0.686629
# Volatility             -0.048228      -0.055395 -0.220847 -0.018862 -0.197205
# SP_500                 -0.189711      -0.274442  0.866468  0.073860  0.849901
#
#                    Unemployment  Savings_Rate  Retail_Sales  \
# 2_YR_Treasury         -0.572556     -0.495530     -0.026162
# Eff_Fed_Funds         -0.577563     -0.454029     -0.018977
# Real_GDP               0.009775      0.464188     -0.026657
# Core_CPI              -0.602841     -0.222176     -0.132346
# PCE                    0.022959      0.542178      0.036925
# Unemployment           1.000000      0.383758      0.073627
# Savings_Rate           0.383758      1.000000      0.140538
# Retail_Sales           0.073627      0.140538      1.000000
# Manufacturing_PMI     -0.066554      0.095367      0.138968
# Consumer_Sent         -0.701481     -0.146389      0.045923
# Liquidity              0.472917      0.417253     -0.072879
# Volatility             0.443982      0.317607     -0.118315
# SP_500                -0.210266      0.539347      0.084439
#
#                    Manufacturing_PMI  Consumer_Sent  Liquidity  Volatility  \
# 2_YR_Treasury              -0.127801       0.442322  -0.569650   -0.048228
# Eff_Fed_Funds              -0.192033       0.500053  -0.552972   -0.055395
# Real_GDP                    0.324651      -0.133408   0.552869   -0.220847
# Core_CPI                   -0.435600       0.259626  -0.351867   -0.018862
# PCE                         0.309231      -0.175094   0.686629   -0.197205
# Unemployment               -0.066554      -0.701481   0.472917    0.443982
# Savings_Rate                0.095367      -0.146389   0.417253    0.317607
# Retail_Sales                0.138968       0.045923  -0.072879   -0.118315
# Manufacturing_PMI           1.000000       0.201906   0.029504   -0.495280
# Consumer_Sent               0.201906       1.000000  -0.638417   -0.359522
# Liquidity                   0.029504      -0.638417   1.000000    0.299831
# Volatility                 -0.495280      -0.359522   0.299831    1.000000
# SP_500                      0.390930      -0.252550   0.361046   -0.147217
#
#                      SP_500
# 2_YR_Treasury     -0.189711
# Eff_Fed_Funds     -0.274442
# Real_GDP           0.866468
# Core_CPI           0.073860
# PCE                0.849901
# Unemployment      -0.210266
# Savings_Rate       0.539347
# Retail_Sales       0.084439
# Manufacturing_PMI  0.390930
# Consumer_Sent     -0.252550
# Liquidity          0.361046
# Volatility        -0.147217
# SP_500             1.000000
